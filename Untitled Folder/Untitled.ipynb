# %%
# %cd ..
# !dir
# !streamlit run app.py
# Out:
# C:\Users\User\Stockanalysis
#  Volume in drive C has no label.
#  Volume Serial Number is B4AA-97A6
#
#  Directory of C:\Users\User\Stockanalysis
#
# 27-12-2025  23:13    <DIR>          .
# 27-12-2025  23:07    <DIR>          ..
# 27-12-2025  23:05    <DIR>          .ipynb_checkpoints
# 27-12-2025  23:13             1,112 app.py
# 27-12-2025  22:13    <DIR>          data
# 27-12-2025  22:52    <DIR>          models
# 27-12-2025  23:11    <DIR>          notebooks
# 27-12-2025  23:18    <DIR>          Untitled Folder
# 27-12-2025  23:05               628 Untitled.ipynb
#                2 File(s)          1,740 bytes
#                7 Dir(s)  800,723,259,392 bytes free

# %%
# !streamlit run app.py
